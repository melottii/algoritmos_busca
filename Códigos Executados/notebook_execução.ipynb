# %% [markdown]
# # Trabalho 1 - Inteligência artificial
#
# Informações básicas:
#
# - O trabalho deve ser submetido até a data limite na atividade do AVA.
# - Deve ser submetido um arquivo compactado contendo os programas desenvolvidos e o relatório em formato pdf.
# - É permitido que os alunos conversem a discutem suas soluções, mas os códigos-fonte devem ser produzidos individualmente. Se forem identificados casos de cola, a nota de todos os alunos envolvidos será zerada.

# %% [markdown]
# ## Configuração de ambiente

# %%
# !python -m pip install opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from drive.MyDrive.Faculdade.IA.Trabalho_1.Resources.main import main

# %%
main()
# Out:
# BFS:	Tempo de execução: 11.06 segundos.
# 	Custo total do caminho: 153.52186130069788.
# 	Numero de passos: 115.
# 	Numero total de nos expandidos: 6701.
#
#
# DFS:	Tempo de execução: 0.02 segundos.
# 	Custo total do caminho: 258.97770542341414.
# 	Numero de passos: 213.
# 	Numero total de nós expandidos: 260.
#
#
# AST:	Tempo de execução: 0.04 segundos.
# 	Custo total do caminho: 157.62236636408622.
# 	Numero de passos: 122.
# 	Numero total de nós expandidos: 124.
#
#
# UCS:	Tempo de execução: 11.11 segundos.
# 	Custo total do caminho: 166.93607486307107.
# 	Numero de passos: 128.
# 	Numero total de nós expandidos: 6704.
